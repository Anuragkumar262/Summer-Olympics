# %% [markdown]
# ## **Summer Olympics Data Analysis Assignment**

# %% [markdown]
# ### ***1. In how many cities Summer Olympics is held so far?***

# %%
import pandas as pd

# %%
df=pd.read_csv('summer.csv')

# %%
#1
print(df["City"].nunique())

print(df["City"].unique())
# Out:
# 22
# ['Athens' 'Paris' 'St Louis' 'London' 'Stockholm' 'Antwerp' 'Amsterdam'
#  'Los Angeles' 'Berlin' 'Helsinki' 'Melbourne / Stockholm' 'Rome' 'Tokyo'
#  'Mexico' 'Munich' 'Montreal' 'Moscow' 'Seoul' 'Barcelona' 'Atlanta'
#  'Sydney' 'Beijing']

# %% [markdown]
# ### **2. Which sport is having most number of Gold Medals so far? (Top 5)**

# %%
#2
df2=df[df["Medal"]=="Gold"]
a=df2["Sport"].value_counts().head()
a.plot(x="Sport",y="Medal",kind="bar",figsize=(15,10))
print(a)
# Out:
# Aquatics      1421
# Athletics     1215
# Rowing         890
# Gymnastics     820
# Fencing        552
# Name: Sport, dtype: int64

# %% [markdown]
# ### **3. Which sport is having most number of medals so far? (Top 5)**

# %%
#3
a=df["Sport"].value_counts().head()
a.plot(x="Sport",y="Medal",kind="bar",figsize=(15,10))
print(a)
# Out:
# Aquatics      4170
# Athletics     3638
# Rowing        2667
# Gymnastics    2307
# Fencing       1613
# Name: Sport, dtype: int64

# %% [markdown]
# ### **4. Which player has won most number of medals? (Top 5)**

# %%
#4
a=df["Athlete"].value_counts().head(13)
a.plot(x="Athlete",y="Medal",kind="bar",figsize=(15,10))
print(a)
# Out:
# PHELPS, Michael         22
# LATYNINA, Larisa        18
# ANDRIANOV, Nikolay      15
# MANGIAROTTI, Edoardo    13
# ONO, Takashi            13
# SHAKHLIN, Boris         13
# COUGHLIN, Natalie       12
# TORRES, Dara            12
# NURMI, Paavo            12
# THOMPSON, Jenny         12
# NEMOV, Alexei           12
# KATO, Sawao             12
# FISCHER, Birgit         12
# Name: Athlete, dtype: int64

# %% [markdown]
# ### **5. Which player has won most number Gold Medals of medals? (Top 5)**

# %%
#5
a=df[df["Medal"]=="Gold"]["Athlete"].value_counts().head(29)
a.plot(x="Athlete",y="Medal",kind="bar",figsize=(15,10))
print(a)
# Out:
# PHELPS, Michael               18
# SPITZ, Mark                    9
# NURMI, Paavo                   9
# LATYNINA, Larisa               9
# LEWIS, Carl                    9
# THOMPSON, Jenny                8
# EWRY, Ray                      8
# KATO, Sawao                    8
# BIONDI, Matthew                8
# FISCHER, Birgit                8
# SHAKHLIN, Boris                7
# CHUKARIN, Viktor Ivanovich     7
# CASLAVSKA, Vera                7
# GEREVICH, Aladar               7
# ANDRIANOV, Nikolay             7
# OTTO, Kristin                  6
# KOVACS, Pal Adam               6
# BOLT, Usain                    6
# KLIMKE, Reiner                 6
# VAN DYKEN, Amy                 6
# VEZZALI, Valentina             6
# SCHERBO, Vitaly                6
# HOY, Chris                     6
# NADI, Nedo                     6
# NAKAYAMA, Akinori              6
# FREDRIKSSON, Gert              6
# KARPATI, Rudolf                6
# VAN INNIS, Hubert              6
# ...

# %% [markdown]
# ### **6. In which year India won first Gold Medal in Summer Olympics?**

# %%
#6
df2=df[df["Medal"]=="Gold"]
min(df2[df2["Country"]=="IND"]["Year"])
# Out:
# 1928

# %% [markdown]
# ### **7. Which event is most popular in terms on number of players? (Top 5)**

# %%
#7
a=df["Event"].value_counts().head()
a.plot(kind="bar",figsize=(15,10))
print(a)
# Out:
# Football            1497
# Hockey              1422
# Team Competition    1147
# Basketball          1012
# Handball             973
# Name: Event, dtype: int64

# %% [markdown]
# ### **8. Which sport is having most female Gold Medalists? (Top 5)**

# %%
#8
df2=df[df["Medal"]=="Gold"]
a=df2[df2["Gender"]=="Women"]["Sport"].value_counts().head()
a.plot(kind="bar",figsize=(15,10))
print(a)
# Out:
# Aquatics      589
# Athletics     389
# Gymnastics    268
# Rowing        217
# Volleyball    166
# Name: Sport, dtype: int64
